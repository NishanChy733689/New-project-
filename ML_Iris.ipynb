# %% [markdown]
# <a href="https://colab.research.google.com/github/NishanChy733689/New-project-/blob/main/ML_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My Iris model**

# %% [markdown]
# ## **Loading libraries**

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading the dataset

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Mining the data

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
setosa=df.loc[df.species=='setosa'].reset_index().drop('index',axis=1)

# %%
setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
versicolor=df.loc[df.species=='versicolor'].reset_index().drop('index',axis=1)

# %%
versicolor.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           7.0          3.2           4.7          1.4  versicolor
# 1           6.4          3.2           4.5          1.5  versicolor
# 2           6.9          3.1           4.9          1.5  versicolor
# 3           5.5          2.3           4.0          1.3  versicolor
# 4           6.5          2.8           4.6          1.5  versicolor

# %%
virginica=df.loc[df.species=='virginica'].reset_index().drop('index',axis=1)

# %%
virginica.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species
# 0           6.3          3.3           6.0          2.5  virginica
# 1           5.8          2.7           5.1          1.9  virginica
# 2           7.1          3.0           5.9          2.1  virginica
# 3           6.3          2.9           5.6          1.8  virginica
# 4           6.5          3.0           5.8          2.2  virginica

# %% [markdown]
# ## Making the regression Model

# %%
model=LinearRegression()

# %%
y=df.species

# %%
x=df.drop('species',axis=1)

# %%
y.replace({'virginica':1,'setosa':2,'versicolor':3},inplace=True)

# %%
trainx, testx, trainy, testy = train_test_split(x, y, test_size=0.2, )

# %%
trainx
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 81            5.5          2.4           3.7          1.0
# 98            5.1          2.5           3.0          1.1
# 9             4.9          3.1           1.5          0.1
# 146           6.3          2.5           5.0          1.9
# 107           7.3          2.9           6.3          1.8
# ..            ...          ...           ...          ...
# 61            5.9          3.0           4.2          1.5
# 106           4.9          2.5           4.5          1.7
# 105           7.6          3.0           6.6          2.1
# 14            5.8          4.0           1.2          0.2
# 141           6.9          3.1           5.1          2.3
#
# [120 rows x 4 columns]

# %%
trainy
# Out:
# 81     3
# 98     3
# 9      2
# 146    1
# 107    1
#       ..
# 61     3
# 106    1
# 105    1
# 14     2
# 141    1
# Name: species, Length: 120, dtype: int64

# %%
model.fit(trainx,trainy)
# Out:
# LinearRegression()

# %%
predictions=list(model.predict(testx))

# %%
prediction_df=pd.DataFrame()#({'prediction':[]})

# %%
prediction_df['prediction']=predictions

# %%
pure=[]
for i in prediction_df.prediction:
  if i >= 1 and i<=2:
    pure.append('virginica')
  elif i>=2 and i <=3:
    pure.append('setosa')
  elif i == 3:
    pure.append('versicolor')

# %%
pure
# Out:
# ['setosa',
#  'setosa',
#  'setosa',
#  'virginica',
#  'virginica',
#  'setosa',
#  'virginica',
#  'setosa',
#  'setosa',
#  'virginica',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica',
#  'setosa',
#  'setosa',
#  'virginica',
#  'setosa',
#  'setosa',
#  'virginica',
#  'setosa',
#  'setosa',
#  'setosa',
#  'virginica']

# %%
pure=[]
for i in testy:
  if i >= 1 and i<=2:
    pure.append('virginica')
  elif i>=2 and i <=3:
    pure.append('setosa')
  elif i==3:
    pure.append('versicolor')

# %%
pure
# Out:
# ['virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica',
#  'virginica',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica']

# %% [markdown]
# ### Find the acuracy of the *model*

# %%
len(predictions)
# Out:
# 30

# %%
sns.lineplot(y=model.predict(testx),x=testy)
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# the model is not so good
#
# ---

# %% [markdown]
# ## Classification Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
classifier=RandomForestClassifier()

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y=df.species
x=df.drop('species',axis=1)

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
trainx, testx, trainy, testy = train_test_split(x, y, test_size=0.2,random_state=20)

# %%
classifier.fit(trainx,trainy)
# Out:
# RandomForestClassifier()

# %%
testx
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 84            5.4          3.0           4.5          1.5
# 122           7.7          2.8           6.7          2.0
# 28            5.2          3.4           1.4          0.2
# 24            4.8          3.4           1.9          0.2
# 75            6.6          3.0           4.4          1.4
# 109           7.2          3.6           6.1          2.5
# 81            5.5          2.4           3.7          1.0
# 98            5.1          2.5           3.0          1.1
# 80            5.5          2.4           3.8          1.1
# 100           6.3          3.3           6.0          2.5
# 124           6.7          3.3           5.7          2.1
# 2             4.7          3.2           1.3          0.2
# 34            4.9          3.1           1.5          0.2
# 44            5.1          3.8           1.9          0.4
# 128           6.4          2.8           5.6          2.1
# ...

# %%
testy==classifier.predict(testx)
# Out:
# 84     True
# 122    True
# 28     True
# 24     True
# 75     True
# 109    True
# 81     True
# 98     True
# 80     True
# 100    True
# 124    True
# 2      True
# 34     True
# 44     True
# 128    True
# 13     True
# 93     True
# 41     True
# 63     True
# 137    True
# 19     True
# 60     True
# 126    True
# 11     True
# 47     True
# 18     True
# 96     True
# 107    True
# 141    True
# 53     True
# Name: species, dtype: bool

# %%
classifier.predict(testx)
# Out:
# array(['versicolor', 'virginica', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor', 'virginica',
#        'virginica', 'setosa', 'setosa', 'setosa', 'virginica', 'setosa',
#        'versicolor', 'setosa', 'versicolor', 'virginica', 'setosa',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'setosa',
#        'versicolor', 'virginica', 'virginica', 'versicolor'], dtype=object)

# %% [markdown]
# # **Wow !!!!! the classifier model is 100 % acurate**
